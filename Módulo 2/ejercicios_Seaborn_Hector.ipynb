# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# # 1. Importa pandas, pyplot y seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
pokemon_prueba = pd.read_csv(r"C:\Users\data_\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\6-Visualización\2-Seaborn\Ejercicios\data\Pokemon.csv")
pokemon_prueba #la primera columna "sin título" es el índice del dataframe o manera 2
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %%
pokemon = pd.read_csv(r"C:\Users\data_\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\6-Visualización\2-Seaborn\Ejercicios\data\Pokemon.csv", index_col=0)
pokemon #manera 2: directamente se lee la primera columna del dataframe como índice
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %% [markdown]
# # 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
pokemon.head(10) #cogemos las 10 primeras filas, por ejemplo
# Out:
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1    Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3     Venusaur  Grass  Poison    525  80      82       83      100      100
# 4   Charmander   Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6    Charizard   Fire  Flying    534  78      84       78      109       85
# 7     Squirtle  Water     NaN    314  44      48       65       50       64
# 8    Wartortle  Water     NaN    405  59      63       80       65       80
# 9    Blastoise  Water     NaN    530  79      83      100       85      105
# 10    Caterpie    Bug     NaN    195  45      30       35       20       20
#
#     Speed  Stage  Legendary
# #
# 1      45      1      False
# 2      60      2      False
# 3      80      3      False
# 4      65      1      False
# 5      80      2      False
# 6     100      3      False
# 7      43      1      False
# 8      58      2      False
# 9      78      3      False
# 10     45      1      False

# %% [markdown]
# # 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# ### Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
#Para graficar, pasas el DataFrame al parámetro "data", y defines los ejes x e y utilizando los nombres de las columnas:
# Scatter plot básico con línea de regresión
sns.lmplot(data=pokemon, x="Attack", y="Sp. Atk") #x e y serán los ejes del gráfico, que hemos elegido esos, por ejemplo
plt.show()

# %% [markdown]
# # 6. No queremos ver la línea recta de la regresión lineal.
# ### prueba a añadir fit_reg a falso

# %%
sns.lmplot(data=pokemon, x="Attack", y="Sp. Atk", fit_reg=False)
plt.show()

# %% [markdown]
# # 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# ### Que el hue sea el Stage

# %%
sns.scatterplot(data=pokemon, x="Attack", y="Sp. Atk", hue="Stage")
plt.show()

# %% [markdown]
# # 8. Limita el eje x entre 20 y 100

# %%
sns.scatterplot(data=pokemon, x="Attack", y="Sp. Atk", hue="Stage") #sobre el ejercicio anterior
plt.xlim(20, 100)
plt.show()

# %% [markdown]
# # 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(data=pokemon) #usaremos todo el dataframe para ello
plt.show()

# %% [markdown]
# # 10. No nos interesan las columnas Total, Stage ni Legendary
# ### Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
new_pokemon = pokemon.drop(columns=['Total', 'Stage','Legendary'])
new_pokemon
# Out:
#            Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur    Grass  Poison   45      49       49       65       65
# 2       Ivysaur    Grass  Poison   60      62       63       80       80
# 3      Venusaur    Grass  Poison   80      82       83      100      100
# 4    Charmander     Fire     NaN   39      52       43       60       50
# 5    Charmeleon     Fire     NaN   58      64       58       80       65
# ..          ...      ...     ...  ...     ...      ...      ...      ...
# 147     Dratini   Dragon     NaN   41      64       45       50       50
# 148   Dragonair   Dragon     NaN   61      84       65       70       70
# 149   Dragonite   Dragon  Flying   91     134       95      100      100
# 150      Mewtwo  Psychic     NaN  106     110       90      154       90
# 151         Mew  Psychic     NaN  100     100      100      100      100
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# ..     ...
# 147     50
# 148     70
# 149     80
# 150    130
# 151    100
#
# [151 rows x 9 columns]

# %%
sns.boxplot(data=new_pokemon) #usaremos todo el dataframe para ello
plt.show()

# %% [markdown]
# # 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
pokemon['Type 1'].nunique() #así vemos cuántos valores diferentes hay en la columna "Type 1" del dataframe
# Out:
# 15

# %%
pokemon['Type 1'].unique() #así vemos los 15 valores diferentes que hay en la columna "Type 1" del dataframe
# Out:
# <StringArray>
# [   'Grass',     'Fire',    'Water',      'Bug',   'Normal',   'Poison',
#  'Electric',   'Ground',    'Fairy', 'Fighting',  'Psychic',     'Rock',
#     'Ghost',      'Ice',   'Dragon']
# Length: 15, dtype: str

# %% [markdown]
# # 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
pokemon[pokemon['Type 1'].isin(['Grass', 'Fire', 'Water'])] #los valores a mantener hay que meterlos en ([])
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire       NaN    309   39      52       43       60
# 5    Charmeleon   Fire       NaN    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water       NaN    314   44      48       65       50
# 8     Wartortle  Water       NaN    405   59      63       80       65
# 9     Blastoise  Water       NaN    530   79      83      100       85
# 37       Vulpix   Fire       NaN    299   38      41       40       50
# 38    Ninetales   Fire       NaN    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water       NaN    320   50      52       48       65
# 55      Golduck  Water       NaN    500   80      82       78       95
# 58    Growlithe   Fire       NaN    350   55      70       45       70
# 59     Arcanine   Fire       NaN    555   90     110       80      100
# 60      Poliwag  Water       NaN    300   40      50       40       40
# 61    Poliwhirl  Water       NaN    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire       NaN    410   50      85       55       65
# 78     Rapidash   Fire       NaN    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water       NaN    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water       NaN    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water       NaN    325   30     105       90       25
# 99      Kingler  Water       NaN    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass       NaN    435   65      55      115      100
# 116      Horsea  Water       NaN    295   30      40       70       70
# 117      Seadra  Water       NaN    440   55      65       95       95
# 118     Goldeen  Water       NaN    320   45      67       60       35
# 119     Seaking  Water       NaN    450   80      92       65       65
# 120      Staryu  Water       NaN    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire       NaN    495   65      95       57      100
# 129    Magikarp  Water       NaN    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water       NaN    525  130      65       60      110
# 136     Flareon   Fire       NaN    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# 6         85    100      3      False
# 7         64     43      1      False
# 8         80     58      2      False
# 9        105     78      3      False
# 37        65     65      1      False
# 38       100    100      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 54        50     55      1      False
# 55        80     85      2      False
# 58        50     60      1      False
# 59        80     95      2      False
# 60        40     90      1      False
# 61        50     90      2      False
# 62        90     70      3      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 77        65     90      1      False
# 78        80    105      2      False
# 79        40     15      1      False
# 80        80     30      2      False
# 86        70     45      1      False
# 87        95     70      2      False
# 90        25     40      1      False
# 91        45     70      2      False
# 98        25     50      1      False
# 99        50     75      2      False
# 102       45     40      1      False
# 103       65     55      2      False
# 114       40     60      1      False
# 116       25     60      1      False
# 117       45     85      2      False
# 118       50     63      1      False
# 119       80     68      2      False
# 120       55     85      1      False
# 121       85    115      2      False
# 126       85     93      1      False
# 129       20     80      1      False
# 130      100     81      2      False
# 131       95     60      1      False
# 134       95     65      2      False
# 136      110     65      2      False
# 146       85     90      1       True

# %%
#le hemos asignado un nombre a este dataframe para futuros ejercicios
pokemon_3_tipos = pokemon[pokemon['Type 1'].isin(['Grass', 'Fire', 'Water'])] #los valores a mantener hay que meterlos en ([])
pokemon_3_tipos
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire       NaN    309   39      52       43       60
# 5    Charmeleon   Fire       NaN    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water       NaN    314   44      48       65       50
# 8     Wartortle  Water       NaN    405   59      63       80       65
# 9     Blastoise  Water       NaN    530   79      83      100       85
# 37       Vulpix   Fire       NaN    299   38      41       40       50
# 38    Ninetales   Fire       NaN    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water       NaN    320   50      52       48       65
# 55      Golduck  Water       NaN    500   80      82       78       95
# 58    Growlithe   Fire       NaN    350   55      70       45       70
# 59     Arcanine   Fire       NaN    555   90     110       80      100
# 60      Poliwag  Water       NaN    300   40      50       40       40
# 61    Poliwhirl  Water       NaN    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire       NaN    410   50      85       55       65
# 78     Rapidash   Fire       NaN    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water       NaN    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water       NaN    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water       NaN    325   30     105       90       25
# 99      Kingler  Water       NaN    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass       NaN    435   65      55      115      100
# 116      Horsea  Water       NaN    295   30      40       70       70
# 117      Seadra  Water       NaN    440   55      65       95       95
# 118     Goldeen  Water       NaN    320   45      67       60       35
# 119     Seaking  Water       NaN    450   80      92       65       65
# 120      Staryu  Water       NaN    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire       NaN    495   65      95       57      100
# 129    Magikarp  Water       NaN    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water       NaN    525  130      65       60      110
# 136     Flareon   Fire       NaN    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# 6         85    100      3      False
# 7         64     43      1      False
# 8         80     58      2      False
# 9        105     78      3      False
# 37        65     65      1      False
# 38       100    100      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 54        50     55      1      False
# 55        80     85      2      False
# 58        50     60      1      False
# 59        80     95      2      False
# 60        40     90      1      False
# 61        50     90      2      False
# 62        90     70      3      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 77        65     90      1      False
# 78        80    105      2      False
# 79        40     15      1      False
# 80        80     30      2      False
# 86        70     45      1      False
# 87        95     70      2      False
# 90        25     40      1      False
# 91        45     70      2      False
# 98        25     50      1      False
# 99        50     75      2      False
# 102       45     40      1      False
# 103       65     55      2      False
# 114       40     60      1      False
# 116       25     60      1      False
# 117       45     85      2      False
# 118       50     63      1      False
# 119       80     68      2      False
# 120       55     85      1      False
# 121       85    115      2      False
# 126       85     93      1      False
# 129       20     80      1      False
# 130      100     81      2      False
# 131       95     60      1      False
# 134       95     65      2      False
# 136      110     65      2      False
# 146       85     90      1       True

# %% [markdown]
# # 13. Usa un estilo 'whitegrid'

# %%
# Configurar el estilo whitegrid
sns.set_style("whitegrid")
# Crear el gráfico. Como no especifica cuál, me cojo el primero que hemos hecho y le añado eñ estilo whitegrid
sns.scatterplot(x="Attack", y="Sp. Atk", data=pokemon)
plt.show()

# %% [markdown]
# # 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

# %%
#los 3 tipos se refieren a "Grass", "Fire" o "Water", por lo que usaremos el dataframe de "pokemon_3_tipos"
sns.violinplot(data=pokemon_3_tipos, x= "Defense", hue="Type 1") #como no especifica qué variables queremos analizar en el violinplot, ponemos en el eje x "Defense"
#por ejemplo. Había puesto en el eje y = "Sp. Def" pero quedaba un diagrama bastante feo, así que lo he quitado.
#Lo importante es que hay que usar el "Type 1" como hue porque es donde vienen los 3 tipos que queremos comparar: Grass, Fire y Water
plt.show()

# %%
sns.violinplot(data=pokemon_3_tipos, y= "Defense", hue="Type 1") #misma prueba cambiando el eje x por el y
plt.show()

# %% [markdown]
# # 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030', '#6890F0']
colores
# Out:
# ['#78C850', '#F08030', '#6890F0']

# %% [markdown]
# # 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(data=pokemon_3_tipos, x= "Defense", hue="Type 1", palette=colores)
plt.show()

# %% [markdown]
# # 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# ### Para ver esto, usamos el swarmplot.
# ### Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(data=pokemon_3_tipos, x="Defense", hue="Type 1", palette=colores, dodge=True) 
plt.show()
#"dodge=True" separa los puntos según el 'hue' para que coincidan con el violín
#es lo único diferente. El resto es como el diagrama de violín

# %% [markdown]
# # 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# ### Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# ### Pon un título con pyplot (como siempre)

# %%
# Diagrama de Violín (sin caja interna). Al final para hacer un gráfico con más condiciones, hay que ir añadiendo estas condiciones dentro del paréntesis:
sns.violinplot(data=pokemon_3_tipos, x="Defense", hue="Type 1", palette=colores, inner=None, alpha=0.9)
#inner=None: elimina los diagramas de caja internos
#alpha=0.9: transparencia solicitada

#Título con Pyplot
plt.title("Aquí va el título");

# %% [markdown]
# # 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# ### Dado un DataFrame, melt recibe varios parámetros:
# ### * qué columnas del DataFrame se quedan igual
# ### * qué nombres de columnas del dataframe pasan a ser una columna nueva
# ### * cómo queremos llamar esas nuevas columnas
#
# ### Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
#el dataframe "df_grass_fire_water" lo he llamado "pokemon_3_tipos"
pokemon_3_tipos.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# la función melt() crea un nuevo dataframe a partir de los datos de un dataframe existente (pasa la información de columnas  a filas):
pokemon_3_tipos.melt(id_vars = ["Name"], value_vars = ["Type 1", "Type 2"], var_name = "Types") #por ejemplo
# id_vars = [''] -> Columnas que se quedan fijas (identificadores)
# value_vars = ['', ''] -> Columnas que se van a "desenrollar"
# var_name = '' -> Nombre para la nueva columna de categorías
# Out:
#            Name   Types   value
# 0     Bulbasaur  Type 1   Grass
# 1       Ivysaur  Type 1   Grass
# 2      Venusaur  Type 1   Grass
# 3    Charmander  Type 1    Fire
# 4    Charmeleon  Type 1    Fire
# ..          ...     ...     ...
# 99     Gyarados  Type 2  Flying
# 100      Lapras  Type 2     Ice
# 101    Vaporeon  Type 2     NaN
# 102     Flareon  Type 2     NaN
# 103     Moltres  Type 2  Flying
#
# [104 rows x 3 columns]

# %% [markdown]
# # 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# ### Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# ### Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
pokemon_3_tipos.melt(id_vars=['Name', 'Type 1'], value_vars=["Attack", "Defense"], var_name='New Column')
#es igual que el ejercicio anterior. Lo único que he cambiado han sido los valores de las columnas id_vars, value_vars y var_name. La función es la misma
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass     Attack     49
# 1       Ivysaur  Grass     Attack     62
# 2      Venusaur  Grass     Attack     82
# 3    Charmander   Fire     Attack     52
# 4    Charmeleon   Fire     Attack     64
# ..          ...    ...        ...    ...
# 99     Gyarados  Water    Defense     79
# 100      Lapras  Water    Defense     80
# 101    Vaporeon  Water    Defense     60
# 102     Flareon   Fire    Defense     60
# 103     Moltres   Fire    Defense     90
#
# [104 rows x 4 columns]

# %% [markdown]
# # 21. Pintamos el swarmplot con el melted y entendemos la información

# %% [markdown]
# # 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# ### En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# ### Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# ## Usando plt
# ### fija el límite del eje Y entre 0 y 200
# ### fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# ### Lo importante es que Seaborn y Pyplot conviven bien juntos

# %% [markdown]
# # 23. Mapas de calor
# ### Calcula las correlaciones del primer DataFrame original df
# ### Pista: las correlaciones se calculan con el método corr()
# ### Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %% [markdown]
# ### ¿la correlación entre qué valores se encuentra?
# ### la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# ### Encuentra dos variables que veas que están fuertemente relacionadas según la correlación

# %% [markdown]
# # 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.set_style("whitegrid")

sns.histplot(pokemon["Defense"], kde =True, bins = 13) #bins = 13 por defecto

plt.title("Defense")
plt.xlabel("Defense level")
plt.ylabel("Frequency/density") #kde es la densidad de la probabilidad

plt.show()

# %% [markdown]
# # 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# ### Usa un sns.countplot
# ### Usa plt.xticks y gira las etiquetas

# %% [markdown]
# # 26. Usa catplot con el DataFrame original.
# ### Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios y divide los colores según el Type 2

# %% [markdown]
# # 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# ### Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %% [markdown]
# # 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original
