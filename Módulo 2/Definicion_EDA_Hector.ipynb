# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# #### "Las Top 100 universidades del mundo"

# %%
#Escribe el título del proyecto en Markdown
titulo = "Las Top 100 universidades del mundo"

# %% [markdown]
# ### TEMA

# %% [markdown]
# #### "Qué factores afectan a que una universidad sea mejor que otra y conseguir un ranking institucional más elevado que sus competidoras"

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Qué factores afectan a que una universidad sea mejor que otra y conseguir un ranking institucional más elevado que sus competidoras"

# %%
# ALTERNATIVA: 
# titulo = "Qué nos dicen los resultados de exámenes de los estudiantes"
# tema = "Qué factores afectan a la hora de sacar una mejor nota"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# #### HIPÓTESIS PRINCIPAL: "Las universidades privadas no son mejores que las públicas"

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "Las universidades privadas no son mejores que las públicas"

# %% [markdown]
# #### HIPÓTESIS 2: "La mayoría de las mejores universidades están en EEUU y son las que más estudiantes han tenido a lo largo de su historia"
# #### HIPÓTESIS 3: "Contra más programas se ofrezcan en la universidad, hay más personal docente"
# #### HIPÓTESIS 4: "Contra más campuses tenga una universidad, más área tiene"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = "La mayoría de las mejores universidades están en EEUU y son las que más estudiantes han tenido a lo largo de su historia"
# hipotesis_3 = "Contra más programas se ofrezcan en la universidad, hay más personal docente"
# hipotesis_4 = "Contra más campuses tenga una universidad, más área tiene"
# ...

# %%
# ALTERNATIVA: 
# hipotesis_principal = "Los estudiantes con una buena organización de estudio tienen más probabilidades de sacar mejor nota" 
# Se tienen en cuenta columnas como Attendence, Hours_Studied, Sleep_Hours y Access_to_Resources	

# subhipotesis_1 = "La importancia de la motivación de un estudiante a la hora de la nota final"
# Se tiene en cuenta la columna "Motivation_Level"

# subhipotesis_2 = "El entorno en el que ha crecido el estudiante no afecta tanto en el rendimiento de los exámenes"
# Se tienen en cuenta columnas como Family_Income, Teacher_Quality, School_Type y Parental_Education_Level

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %%
# guarda en variables los datasets y su fuente
# df_1 = pd.DataFrame()
# fuente_1 = ""
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

dataset = pd.read_csv(r"C:\Users\data_\.cache\kagglehub\datasets\syedaeman2212\top-100-universities\versions\1\top_100_universities_dataset.csv")
dataset
#fuente= "Kaggle" https://www.kaggle.com/datasets/syedaeman2212/top-100-universities/data

#La columna "Location" está mal. Habrá que arreglarlo
#La columna "Total_Faculty" se refiere al staff total que hay en esa universidad
#En la última columna "Acres" significa la medida de superficie del campus en el sistema de medición estadounidense
# Out:
#     Position          University_Name                Location  \
# 0          1     University of Oxford  Cambridge, Switzerland
# 1          2      Columbia University         Stanford, China
# 2          3   University of Michigan        Cambridge, China
# 3          4  University of Edinburgh          Singapore, USA
# 4          5  University of Cambridge     London, Switzerland
# ..       ...                      ...                     ...
# 95        96          Yale University  Singapore, Switzerland
# 96        97      Columbia University           Ann Arbor, UK
# 97        98        Peking University  Edinburgh, Switzerland
# 98        99                      UCL        Cambridge, China
# 99       100  University of Cambridge     New York, Singapore
#
#     Established_Year  Total_Students  Number_of_Campuses  Programs_Offered  \
# 0               1250           19628                   3               427
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
dataset.head()
# Out:
#    Position          University_Name                Location  \
# 0         1     University of Oxford  Cambridge, Switzerland
# 1         2      Columbia University         Stanford, China
# 2         3   University of Michigan        Cambridge, China
# 3         4  University of Edinburgh          Singapore, USA
# 4         5  University of Cambridge     London, Switzerland
#
#    Established_Year  Total_Students  Number_of_Campuses  Programs_Offered  \
# 0              1250           19628                   3               427
# 1              1432            7082                   1                97
# 2              1203           51925                  11               409
# 3              1777           57810                   3               407
# 4              1104           11078                   7                99
#
#   University_Type  Total_Faculty  Campus_Area_Acres
# 0          Public           5843               6167
# ...

# %%
# ALTERNATIVA:
students = pd.read_csv(r"C:\Users\data_\.cache\kagglehub\datasets\grandmaster07\student-exam-performance-dataset-analysis\versions\1\StudentPerformanceFactors.csv")
students
#fuente= "Kaggle" https://www.kaggle.com/datasets/grandmaster07/student-exam-performance-dataset-analysis/data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
students.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...
