# %% [markdown]
# ## Mini Hundir la Flota
# #### Primeros pasos
# Vamos a empezar a programar trozos de código que nos servirán para el HLF:
#
# * Crear un Tablero como una lista de listas de 10x10 que contenga caracteres espacio: " "
# * Insertar dos barcos sustituyendo en el Tablero los espacios en blanco por el caracter "B":
#     * Uno de 4 casillas en horizontal: casillas [1][0], [1][1], [1][2], [1][3]
#     * Uno de 3 casillas en vertical:   casillas [3][3], [4][3], [5][3]
# * Escribir una celda de código separada de las anteriores para simular que el usuario está efectuando un disparo:
#     *  Solicite al usuario dos coordenadas `i,j` mediante dos inputs
#     *  Compruebe si esas coordenadas están ocupada por una casilla barco (que haya una en "B")
#         * Si hay una "B":
#             * Cambiar el contenido de esa posición por una "x"
#             * Imprimir por pantalla el texto "Tocado en posición `i,j`"
#         * Si hay un " ":
#             * Cambiar el contenido de esa posición por una "o"
#             * Imprimir por pantalla el texto "Agua"
#     * Imprimir por pantalla el Tablero
# * Para comprobar que funciona bien la celda de disparar ejecutarla varias veces metiendo distintas coordenadas
#
# ### Bonus
# * En la celda de disparar, si el usuario acierta a tocar un barco, vuelve a disparar
# * Resuélvelo con funciones:
#     * Una para solicitar una coordenada válida a la que llamarás dos veces, una par i y otra par j
#     * Una `disparar` que devuelva `True` si el usuario ha acertado o `False` si no.

# %%
#Vamos a hacer los pasos 1 a 1 para probar que funcionan
#He consultado en internet para hacer este ejercicio
#Estos pasos son la manera más fácil que he encontrado que pueda entender. Jamás se me habría ocurrido hacerlo así

# %%
#PASO 1: Crear un Tablero como una lista de listas de 10x10 que contenga caracteres espacio: " " 

tablero = [] #se empieza con una lista vacía y le añadiremos filas (i) y columnas (j) de un rango de 10
for i in range(10):
    fila = [] #se crea la lista vacía de filas
    for j in range(10): #este bucle 'for' está dentro para que haya una columna por cada fila - para que estén asociadas (o eso creo)
        fila.append(" ") #para cada columna (y en consecuencia, cada fila) se le añade el espacio - ¿al final de la lista?
    tablero.append(fila) #a la lista vacía 'tablero', se le añade el bucle entero al final
    
print(tablero)
    
#Así tenemos la lista "tablero" de 10 filas y 1o columnas (10 listas con 10 elementos) con espacios en blanco
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
#PASO 2: Insertar dos barcos sustituyendo en el Tablero los espacios en blanco por el caracter "B":
    #* Uno de 4 casillas en horizontal: casillas [1][0], [1][1], [1][2], [1][3]
    #* Uno de 3 casillas en vertical: casillas [3][3], [4][3], [5][3]
    
#Yo no quería usar un bucle para esto. Prefería usar un comando tipo "insert" pero al hacer tablero.insert([1][0], "B") me salía la "B" fuera de la lista.
#Este comando añade, no sustituye elementos. Me he decantado por el bucle porque es lo más fácil que he encontrado pero me da error:

for tablero_con_barcos in tablero: #"tablero_con_barcos" entiendo que es una variable de "tablero" con la que queremos cambiar los elementos de las posiciones
    for i in range(len(tablero_con_barcos)): #"i" se refiere a las posiciones que hay en todo el rango de la longitud de "tablero_con_barcos". ¿El range no sobra?
        if tablero_con_barcos[1][0] == " ":
            tablero_con_barcos[1][0] = "B" #debería funcionar porque todos los elementos de cada lista, son strings
            #habría que ir añadiendo todo "elif"s con cada posición de los barcos

print(tablero)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 11
#       9     for i in range(len(tablero_con_barcos)): #"i" se refiere a las posiciones que hay en todo el rango de la longitud de "tablero_con_barcos". ¿El range no sobra?
#      10         if tablero_con_barcos[1][0] == " ":
# ---> 11             tablero_con_barcos[1][0] = "B" #debería funcionar porque todos los elementos de cada lista, son strings
#      12             #habría que ir añadiendo todo "elif"s con cada posición de los barcos
#      14 print(tablero)
#
# TypeError: 'str' object does not support item assignment

# %%
'''PASO 3: Escribir una celda de código separada de las anteriores para simular que el usuario está efectuando un disparo: 
    *  Solicite al usuario dos coordenadas `i,j` mediante dos inputs
    *  Compruebe si esas coordenadas están ocupada por una casilla barco (que haya una en "B")
        * Si hay una "B":
            * Cambiar el contenido de esa posición por una "x"
            * Imprimir por pantalla el texto "Tocado en posición `i,j`"
        * Si hay un " ":
            * Cambiar el contenido de esa posición por una "o"
            * Imprimir por pantalla el texto "Agua"
    * Imprimir por pantalla el Tablero
* Para comprobar que funciona bien la celda de disparar ejecutarla varias veces metiendo distintas coordenadas

# %%
#Aunque no me haya salido el paso anterior, voy a probar los comandos de este paso:

coordenada_i = input("Meta la fila deseada. Valores 0-9:") #fila
coordenada_j = input("Meta la columna deseada. Valores 0-9:") #columna
print(coordenada_i, coordenada_j) 
#suponiendo que ya tendríamos las Bs puestas:
for posición, valor in enumerate(tablero): #posición serían "i" y "j" y valor serían "coordenada_i" y "coordenada_j" pero no sé cómo ponerlo al haber 2 de cada
    if coordenada_i == "B": 
        if coordenada_j == "B":
            tablero[i][j] = "x"
            print("Tocado en", coordenada_i, coordenada_j)
    elif coordenada_i == " " or coordenada_j == " ": #sin haber definido las Bs, debería dar siempre esto pero no printea "Agua"
        tablero[i][j] = "o"
        print("Agua")
print(tablero)
# Out:
# 8 5
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
#Voy a hacer una versión libre porque teniendo un error en el paso anterior, va a ser difícil comprobar nada sino. Aún así, siempre sale "Agua"
# [1][0], [1][1], [1][2], [1][3], [3][3], [4][3], [5][3]:
coordenada_i = input("Meta la fila deseada. Valores 0-9:") #fila
coordenada_j = input("Meta la columna deseada. Valores 0-9:") #columna
print(coordenada_i, coordenada_j)
if coordenada_i == 1 and coordenada_j == 0:
    print("Tocado en posición 1,0")
elif coordenada_i == 1 and coordenada_j == 1:
    print("Tocado en posición 1,1")
elif coordenada_i == 1 and coordenada_j == 2:
    print("Tocado en posición 1,2")
elif coordenada_i == 1 and coordenada_j == 3:
    print("Tocado en posición 1,3")
elif coordenada_i == 3 and coordenada_j == 3:
    print("Tocado en posición 3,3")
elif coordenada_i == 4 and coordenada_j == 3:
    print("Tocado en posición 4,3")
elif coordenada_i == 5 and coordenada_j == 3:
    print("Tocado en posición 5,3")
else:
    print("Agua")
# Out:
# 1 0
# Agua
