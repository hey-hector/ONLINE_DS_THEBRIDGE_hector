# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print('¿Por qué esta magnífica tecnología cinetífica,\n\t que ahorra trabajo y nos hace la vida más fácil,\n\t\t nos aporta tan poca felicidad?\n\t\t\t La respuesta es esta, simplemente: porque aún no hemos aprendido a usarla con tino.\n"Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología cinetífica,
# 	 que ahorra trabajo y nos hace la vida más fácil,
# 		 nos aporta tan poca felicidad?
# 			 La respuesta es esta, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = "Nicolás"
número = 4
ciudad = "Bilbao"
cp = 48003
print(calle, número, ciudad, cp)
# Out:
# Nicolás 4 Bilbao 48003

# %%
provincia = "Bizkaia"
print(calle, número, ciudad, cp, provincia)
# Out:
# giroa 8 Carta 85479 Bizkaia

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input("Calle")
número = input("Número")
ciudad = input("Ciudad")
cp = input("Código Postal")
print(f"Su dirección es calle {calle}, Nº {número}\n{ciudad}, {cp}")
# Out:
# Su dirección es calle giroa, Nº 8
# Carta, 85479

# %%
provincia = input("Provincia")
print(f"Su dirección completa es calle {calle}, Nº {número}\n{ciudad}, {cp}, {provincia}")
# Out:
# Su dirección completa es calle giroa, Nº 8
# Carta, 85479, Bis

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %%
mi_variable = "Economía"
print(mi_variable) #correcto: variable tipo string (str)
"""
otra_var = "Ejercicio
print(otra_var) #incorrecto: no se han cerrado las comillas 
True = "Ejercicio" 
print(True) #la palabra "True" es un output booleano, por lo que no se puede definir como el nombre de una variable
mi variab1e = "Alpha"
print (mi variable) #el nombre de la variable tiene un espacio, por lo que da error. Debería de ser: mi_variable
import = 40
print(import) #import es una función para importar módulos, por lo que no puede ser el nombre de una variable
81mi_variable = "Agua"
print(81mi_variable) #el nombre de una variable no puede empezar por un número porque da error. Debería de ser: mi_variable81
"""
mi_variable10 = 6
print(mi_variable10) #correcto: hay barra baja entre las palabras y los números para definir la variable están al final. Variable tipo int (número entero)
# Out:
# Economía
# 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
celsius = input("Grados Celsius")
celsius_float = float(celsius)
fahrenheit = celsius_float * (9/5) + 32
print("Grados Fahrenheit", fahrenheit)
# Out:
# Grados Fahrenheit 105.44

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
'''
Se pone el input para que el usuario pueda meter sus grados Celsius
Como los inputs siempre son en formato string (str), es necesario cambiarlo a formato float (con decimales
Una vez que tenemos los grados Celsius en formato float, se puede hacer la operación de conversión a grados Fahrenheit
Por último, imprimimos el texto deseado y los resultados de la operación de la línea anterior
'''
